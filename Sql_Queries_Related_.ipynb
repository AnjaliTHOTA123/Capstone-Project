# %%
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector as sql

# %%
#pip install SQLAlchemy

# %%
import mysql.connector as sql

con_sql=sql.connect(host="localhost",user="root",password="Anjali@2001",database="hr")
if con_sql.is_connected:
   print("connected")
else:
  print("not connected")
# Out:
# connected

# %%
df = pd.read_csv('FootBall_Data_Merged_Cleaned.csv')
df=df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#        appearance_id    game_id  player_id                 date  \
# 0     2224728_119169  2224728.0     119169  2012-07-13 00:00:00
# 1     2232104_119169  2232104.0     119169  2012-07-19 00:00:00
# 2     2224568_119169  2224568.0     119169  2012-07-23 00:00:00
# 3     2244352_119169  2244352.0     119169  2012-07-26 00:00:00
# 4     2224567_119169  2224567.0     119169  2012-07-29 00:00:00
# ...              ...        ...        ...                  ...
# 4649   Not Available  2757218.0     605144        Not Available
# 4650   Not Available  2757218.0     623872        Not Available
# 4651   Not Available  2757218.0     467437        Not Available
# 4652   Not Available  2757218.0     103559        Not Available
# 4653   Not Available  2757218.0     670096        Not Available
#
#         player_name_x competition_id_x  yellow_cards  red_cards  goals  \
# 0     Aron Johannsson              DK1           0.0        0.0    0.0
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import pymysql 
import matplotlib.pyplot as plt

hostname = "localhost"
dbname = "hr"
uname = "root"
pwd = "Anjali@2001"
enc_pwd = quote_plus(pwd)

eng= create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}".format(host=hostname,db=dbname,user=uname,pw=enc_pwd))

# %%
# Write the DataFrame to a SQL table in the 'hr' MySQL database
# The table will be named 'FootBall_Data_Merged_Cleaned', and if it exists, it will be replaced
#df.to_sql('FootBall_Data_Set', con=eng, if_exists='replace', index=False)

# Verify the DataFrame (optional)
print(df)
# Out:
#        appearance_id    game_id  player_id                 date  \
# 0     2224728_119169  2224728.0     119169  2012-07-13 00:00:00
# 1     2232104_119169  2232104.0     119169  2012-07-19 00:00:00
# 2     2224568_119169  2224568.0     119169  2012-07-23 00:00:00
# 3     2244352_119169  2244352.0     119169  2012-07-26 00:00:00
# 4     2224567_119169  2224567.0     119169  2012-07-29 00:00:00
# ...              ...        ...        ...                  ...
# 4649   Not Available  2757218.0     605144        Not Available
# 4650   Not Available  2757218.0     623872        Not Available
# 4651   Not Available  2757218.0     467437        Not Available
# 4652   Not Available  2757218.0     103559        Not Available
# 4653   Not Available  2757218.0     670096        Not Available
#
#         player_name_x competition_id_x  yellow_cards  red_cards  goals  \
# 0     Aron Johannsson              DK1           0.0        0.0    0.0
# ...
